# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据
mnist=input_data.read_data_sets("E:\sxl_Programs\Python\MNIST_data\MNIST_data",one_hot=True)

#每个批次的大小
batch_size=20
#计算一共有多少个批次
n_batch=mnist.train.num_examples // batch_size

#定义两个placeholder
x=tf.placeholder(tf.float32,[None,784])
y=tf.placeholder(tf.float32,[None,10])

#创建一个简单的神经网络
W=tf.Variable(tf.zeros([784,10]))
b=tf.Variable(tf.zeros([10]))
prediction=tf.nn.softmax(tf.matmul(x,W)+b)

#二次代价函数
loss=tf.reduce_mean(tf.square(y-prediction))
#交叉熵
# loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y,logits=prediction))
#使用梯度下降算法
train_step=tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init=tf.global_variables_initializer()

#结果存放在一个布尔型列表中
correct_prediction=tf.equal(tf.argmax(y,1),tf.argmax(prediction,1)) #argmax返回一位数组中最大值的下标
#求准确率
accuracy=tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs,batch_ys=mnist.train.next_batch(batch_size)
            sess.run(train_step,feed_dict={x:batch_xs,y:batch_ys})
        acc=sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print("Iter"+str(epoch)+",Testing Accuracy"+str(acc))
# Out:
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\train-images-idx3-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\train-labels-idx1-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting E:\sxl_Programs\Python\MNIST_data\MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy0.8935
# Iter1,Testing Accuracy0.9048
# Iter2,Testing Accuracy0.9101
# Iter3,Testing Accuracy0.9118
# Iter4,Testing Accuracy0.917
# Iter5,Testing Accuracy0.9168
# Iter6,Testing Accuracy0.9185
# Iter7,Testing Accuracy0.9197
# Iter8,Testing Accuracy0.9209
# Iter9,Testing Accuracy0.9206
# Iter10,Testing Accuracy0.9218
# Iter11,Testing Accuracy0.9228
# Iter12,Testing Accuracy0.9233
# Iter13,Testing Accuracy0.9228
# Iter14,Testing Accuracy0.9228
# Iter15,Testing Accuracy0.9235
# Iter16,Testing Accuracy0.924
# Iter17,Testing Accuracy0.9258
# Iter18,Testing Accuracy0.9253
# Iter19,Testing Accuracy0.9263
# Iter20,Testing Accuracy0.9257

# %%
#二次函数
Iter0,Testing Accuracy0.8776
Iter1,Testing Accuracy0.8927
Iter2,Testing Accuracy0.9019
Iter3,Testing Accuracy0.9054
Iter4,Testing Accuracy0.9079
Iter5,Testing Accuracy0.9103
Iter6,Testing Accuracy0.9121
Iter7,Testing Accuracy0.9133
Iter8,Testing Accuracy0.9143
Iter9,Testing Accuracy0.9159
Iter10,Testing Accuracy0.9174
Iter11,Testing Accuracy0.9174
Iter12,Testing Accuracy0.9185
Iter13,Testing Accuracy0.9186
Iter14,Testing Accuracy0.9193
Iter15,Testing Accuracy0.9201
Iter16,Testing Accuracy0.9201
Iter17,Testing Accuracy0.921
Iter18,Testing Accuracy0.9214
Iter19,Testing Accuracy0.9212
Iter20,Testing Accuracy0.9208

#交叉熵
Iter0,Testing Accuracy0.9065
Iter1,Testing Accuracy0.9166
Iter2,Testing Accuracy0.92
Iter3,Testing Accuracy0.9213
Iter4,Testing Accuracy0.9222
Iter5,Testing Accuracy0.924
Iter6,Testing Accuracy0.9245
Iter7,Testing Accuracy0.924
Iter8,Testing Accuracy0.9261
Iter9,Testing Accuracy0.9258
Iter10,Testing Accuracy0.9274
Iter11,Testing Accuracy0.926
Iter12,Testing Accuracy0.9263
Iter13,Testing Accuracy0.928
Iter14,Testing Accuracy0.9269
Iter15,Testing Accuracy0.9273
Iter16,Testing Accuracy0.9274
Iter17,Testing Accuracy0.9274
Iter18,Testing Accuracy0.9275
Iter19,Testing Accuracy0.9293
Iter20,Testing Accuracy0.9278
